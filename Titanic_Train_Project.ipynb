# %% [markdown]
# # Titanic_train Project

# %%
#Create with 30 records
import matplotlib.pyplot as plt
import numpy as np
import pandas
df=pandas.read_csv("titanic_train.csv")
print(df)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
import pandas
df=pandas.read_csv("titanic_train.csv", index_col=['PassengerId'])
print(df)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
df['Fare'].max()

# %%
df['Fare'].min()

# %%
df['Ticket'].max()

# %%
df['Ticket'].min()

# %%
df["Survived"].plot.bar()

# %%
plt.violinplot(df["Fare"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x2abe95f44c0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2abe95f4340>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2abe95f43a0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2abe95f4910>}

# %%
df["Fare"].plot.bar()

# %%
plt.boxplot(df["Survived"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2abe96a8e20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2abe96b8520>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2abe96a8ac0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2abe96b8be0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2abe96b8ee0>],
#  'means': []}

# %%
df.loc[:,"Fare"]
# Out:
# PassengerId
# 1       7.2500
# 2      71.2833
# 3       7.9250
# 4      53.1000
# 5       8.0500
# 6       8.4583
# 7      51.8625
# 8      21.0750
# 9      11.1333
# 10     30.0708
# 11     16.7000
# 12     26.5500
# 13      8.0500
# 14     31.2750
# 15      7.8542
# 16     16.0000
# 17     29.1250
# 18     13.0000
# 19     18.0000
# 20      7.2250
# 21     26.0000
# 22     13.0000
# 23      8.0292
# 24     35.5000
# 25     21.0750
# 26     31.3875
# 27      7.2250
# 28    263.0000
# 29      7.8792
# 30      7.8958
# Name: Fare, dtype: float64

# %%
df.iloc[:,-3:-1]
# Out:
#                  Fare        Cabin
# PassengerId
# 1              7.2500          NaN
# 2             71.2833          C85
# 3              7.9250          NaN
# 4             53.1000         C123
# 5              8.0500          NaN
# 6              8.4583          NaN
# 7             51.8625          E46
# 8             21.0750          NaN
# 9             11.1333          NaN
# 10            30.0708          NaN
# 11            16.7000           G6
# 12            26.5500         C103
# 13             8.0500          NaN
# 14            31.2750          NaN
# 15             7.8542          NaN
# 16            16.0000          NaN
# 17            29.1250          NaN
# 18            13.0000          NaN
# 19            18.0000          NaN
# 20             7.2250          NaN
# 21            26.0000          NaN
# 22            13.0000          D56
# 23             8.0292          NaN
# 24            35.5000           A6
# 25            21.0750          NaN
# ...

# %%
df.iloc[:,0:10]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
df.loc[:,['Name','Ticket','Sex','Fare','Survived']]
# Out:
#                                                           Name  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                       Heikkinen, Miss. Laina
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                     Allen, Mr. William Henry
# 6                                             Moran, Mr. James
# 7                                      McCarthy, Mr. Timothy J
# 8                               Palsson, Master. Gosta Leonard
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                         Nasser, Mrs. Nicholas (Adele Achem)
# 11                             Sandstrom, Miss. Marguerite Rut
# 12                                    Bonnell, Miss. Elizabeth
# 13                              Saundercock, Mr. William Henry
# 14                                 Andersson, Mr. Anders Johan
# ...

# %%
df['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216'], dtype=object)

# %%
df['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
print(df['Name'].describe())
# Out:
# count                                       30
# unique                                      30
# top       Vestrom, Miss. Hulda Amanda Adolfina
# freq                                         1
# Name: Name, dtype: object

# %%
df.describe()
# Out:
#         Survived     Pclass        Age      SibSp      Parch        Fare
# count  30.000000  30.000000  24.000000  30.000000  30.000000   30.000000
# mean    0.500000   2.433333  27.208333   0.700000   0.600000   28.832637
# std     0.508548   0.817200  15.986351   1.118805   1.328728   46.998765
# min     0.000000   1.000000   2.000000   0.000000   0.000000    7.225000
# 25%     0.000000   2.000000  14.750000   0.000000   0.000000    8.034400
# 50%     0.500000   3.000000  27.500000   0.000000   0.000000   16.350000
# 75%     1.000000   3.000000  35.750000   1.000000   0.750000   29.834350
# max     1.000000   3.000000  58.000000   4.000000   5.000000  263.000000

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Pclass"].value_counts()
# Out:
# 3    19
# 1     6
# 2     5
# Name: Pclass, dtype: int64

# %%
df["Parch"].value_counts()
# Out:
# 0    22
# 1     4
# 5     2
# 2     2
# Name: Parch, dtype: int64

# %%
df.isnull().sum()
# Out:
# Survived     0
# Pclass       0
# Name         0
# Sex          0
# Age          6
# SibSp        0
# Parch        0
# Ticket       0
# Fare         0
# Cabin       22
# Embarked     0
# dtype: int64

# %%
#Checking skewness
df.skew()
# Out:
# Survived    0.000000
# Pclass     -0.989604
# Age         0.193960
# SibSp       1.753853
# Parch       2.698775
# Fare        4.563024
# dtype: float64

# %%
#Define Train Fare and Passengerclass
import seaborn as sn
import numpy as np
import matplotlib.pyplot as plt

sn.distplot(df["Fare"])
plt.title("Train Fare")
plt.show()

# %%
sn.distplot(df["Pclass"])
plt.title("PassengerClass")
plt.show()

# %%
#Defien gender count Plot
sn.countplot(df["Sex"])
plt.title("Gender")
plt.show()
