# %%
import pandas as pd
df=pd.read_csv("Employee_1000.csv")
print(df)
df.head()
df.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
df.shape #checking data dimension
# Out:
# (1000, 36)

# %%
#Rename columns Name
df=df.rename(columns={'Middle Initial':'Middle Name', 'Age in Yrs.':'Age','Date of Birth':'DOB', "Mother's Maiden Name":'Mothers M Name', 'Place Name':'Place','Time of Birth':'TOB','Weight in Kgs.':'Weight','Date of Joining':'DOJ','Age in Company (Years)':'Age in Comp'})
df.head()
# Out:
#        Name Prefix First Name Middle Name  Last Name Gender  \
# Emp ID
# 850297         Ms.     Shawna           W       Buck      F
# 304721         Mr.  Nathaniel           Z      Burke      M
# 412317        Drs.  Elisabeth           W     Foster      F
# 621375        Mrs.     Briana           C  Lancaster      F
# 787549        Hon.    Estella           L     Potter      F
#
#                              E Mail      Father's Name     Mother's Name  \
# Emp ID
# 850297        shawna.buck@gmail.com       Rosario Buck       Keisha Buck
# 304721  nathaniel.burke@walmart.com      Derrick Burke      Phoebe Burke
# 412317   elisabeth.foster@gmail.com       Irwin Foster      Janie Foster
# 621375   briana.lancaster@yahoo.com  Jeffrey Lancaster  Shelby Lancaster
# 787549     estella.potter@gmail.com      Booker Potter    Katelyn Potter
#
#        Mothers M Name         DOB  ...          SSN    Phone No.       Place  \
# Emp ID                             ...
# ...

# %%
df.describe()
# Out:
#                Age       Weight  Year of Joining  Month of Joining  \
# count  1000.000000  1000.000000      1000.000000       1000.000000
# mean     40.377250    59.409000      2006.992000          6.415000
# std      11.107729    13.900322         8.565588          3.428488
# min      21.040000    40.000000      1980.000000          1.000000
# 25%      30.925000    49.000000      2002.000000          4.000000
# 50%      40.730000    57.000000      2009.000000          6.000000
# 75%      49.852500    68.000000      2014.000000         10.000000
# max      59.980000    90.000000      2017.000000         12.000000
#
#        Day of Joining  Age in Comp         Salary           Zip
# count     1000.000000  1000.000000    1000.000000   1000.000000
# mean        16.481000    10.093720  120288.528000  48698.499000
# std          8.831514     8.568863   45178.339916  27396.021481
# min          1.000000     0.000000   40040.000000   1002.000000
# ...

# %%
max_m=df['Last % Hike'].max()
max_m
# Out:
# '9%'

# %%
min_m=df['Last % Hike'].min()
min_m
# Out:
# '0%'

# %%
df1=df.drop("Mother's Maiden Name",axis=1)
df1
# Out:
#      Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0    850297         Ms.     Shawna              W       Buck      F
# 1    304721         Mr.  Nathaniel              Z      Burke      M
# 2    412317        Drs.  Elisabeth              W     Foster      F
# 3    621375        Mrs.     Briana              C  Lancaster      F
# 4    787549        Hon.    Estella              L     Potter      F
# ..      ...         ...        ...            ...        ...    ...
# 995  568435         Ms.     Bonnie              K      Baker      F
# 996  597409         Mr.       Luke              S     Turner      M
# 997  359608        Hon.        Eva              S     Holman      F
# 998  803426        Mrs.    Maritza              H  Christian      F
# 999  669618        Drs.    Phyllis              H     Dudley      F
#
#                               E Mail      Father's Name        Mother's Name  \
# ...

# %%
plt.boxplot(df["Emp ID"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x187134888e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18713488fa0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18713488580>],
#  'medians': [<matplotlib.lines.Line2D at 0x187134956a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x187134959a0>],
#  'means': []}

# %%
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np

plt.hist(df["Emp ID"],bins=5)
plt.title('Emp ID')
plt.show()

# %%
plt.violinplot(df["Zip"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x18713288a60>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x187132888b0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x187132888e0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x187132b41c0>}

# %%
corr=df.corr()
sn.heatmap(corr, annot=True)
plt.show()
